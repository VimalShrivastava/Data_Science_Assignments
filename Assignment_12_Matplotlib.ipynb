# %% [markdown]
# **Q1:** What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# **Ans:** Matplotlib is a 2D plotting library for Python that produces high-quality charts, graphs, and figures.
#
# Matplotlib is widely used for data visualization due to its flexibility and ease of use. It allows users to create a variety of plots, charts, and visualizations.
#
# Five plots that can be plotted using the Pyplot module of Matplotlib:
# 1. Line Plot
# 2. Scatter Plot
# 3. Histogram
# 4. Bar Chart
# 5. Pie Chart

# %% [markdown]
# **Q2:** What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# **Ans:** A scatter plot is a type of data visualization that displays individual data points on a two-dimensional graph. Each point represents the values of two variables and can reveal patterns or relationships between them. Scatter plots are useful for identifying correlations, clusters, or trends in the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(3)

# Generate data for x and y
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Plotting Scatter Plot
plt.scatter(x, y)

# Adding title, xlabel, and ylabel
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Display the plot
plt.show()

# %% [markdown]
# **Q3:** Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# **Ans:**The subplot() function in Matplotlib is used to create a grid of subplots within a single figure. This allows to display multiple plots in the same figure, making it easier to compare and analyze different datasets or visualizations. The subplot() function takes three arguments: the number of rows, the number of columns, and the index of the current subplot.

# %%
# Data for four lines
x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a 2x2 grid of subplots
plt.subplot(2, 2, 1)
plt.plot(x, y1, color='blue')
plt.title('Line 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2, color='green')
plt.title('Line 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3, color='red')
plt.title('Line 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4, color='purple')
plt.title('Line 4')

# Adjust layout to prevent overlapping
plt.tight_layout()

# Display the figure
plt.show()

# %% [markdown]
# **Q4:** What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# **Ans:** A bar plot (or bar chart) is a type of data visualization that presents categorical data with rectangular bars.
#
# Bar plots are used to visually represent and compare discrete categories or groups. They are effective in conveying information about the relative sizes or frequencies of different items. Bar plots make it easy to observe patterns, trends, and variations in the data.

# %%
# Data
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar Plot
plt.figure(figsize=(8, 5))
plt.bar(company, profit, color='blue')
plt.title('Profit by Company (Bar Plot)')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.show()

# Horizontal Bar Plot
plt.figure(figsize=(8, 5))
plt.barh(company, profit, color='green')
plt.title('Profit by Company (Horizontal Bar Plot)')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# **Q5:** What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# **Ans:** A box plot is a statistical representation of the distribution of a dataset. It displays the summary of a set of data values, including the minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum.
#
# Box plots are used to provide a concise summary of the distribution of a dataset. They are particularly helpful for identifying the central tendency, spread, and skewness of the data, as well as detecting potential outliers. Box plots are commonly used in statistical analysis and exploratory data analysis.

# %%
# Data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Combine the data into a list
data = [box1, box2]

# Create a box plot
plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.title('Box Plot of Box1 and Box2')
plt.xlabel('Box')
plt.ylabel('Values')

# Display the plot
plt.show()
